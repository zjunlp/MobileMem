# %%
import json
import random
from datetime import datetime, timedelta
from pathlib import Path

from keme.models import Person, Session
from keme.models.persona import (
    BasicInfo,
    Personality,
    Career,
    Diet,
    Health,
    Restaurants,
    Sport,
    Pet,
    Shopping,
    Transportation,
    Car,
    LongTravel,
    Technology,
    Photography,
    Entertainment,
    Finance,
    SocialCircle,
)
from keme.models.app_interactions import (
    VoiceMemoInteraction,
    CalendarInteraction,
    NoteInteraction,
    TodoInteraction,
    BillInteraction,
    DocumentInteraction,
    ScreenInteraction,
)

# Paths
USER_DATA_DIR = Path("./data/user_02/raw")
OUTPUT_PATH = Path("./data/user_02/processed/person.json")

# Data file paths
NOTE_PATH = USER_DATA_DIR / "note" / "batch_note.json"
CALENDAR_PATH = USER_DATA_DIR / "calendar" / "batch_calendar.json"
VOICE_PATH = USER_DATA_DIR / "voice" / "batch_voice_memo.json"
TODO_PATH = USER_DATA_DIR / "todo" / "batch_todo.json"
BILL_PATH = USER_DATA_DIR / "bill" / "batch_bill.json"
DOCUMENT_PATH = USER_DATA_DIR / "document" / "batch_document.json"
SCREEN_DIR = USER_DATA_DIR / "screen"

# Reproducibility (screen memo timestamps are randomly sampled within the persona trajectory window)
RANDOM_SEED = 42
rng = random.Random(RANDOM_SEED)

# %%
def create_person(trajectory_start: str, trajectory_end: str) -> Person:
    """Create Person object based on user01_persona.txt"""
    
    # 基本信息维度
    basic_info = BasicInfo(
        gender="male",
        age=32,
        marital_status="已婚",
        location="浙江省杭州市南华区",
        hometown="浙江杭州",
        economic_status="较好",
        description="32岁男性，非单身，居住在浙江省杭州市，就职于阿里巴巴公司，科技公司中层管理者，技术研发方向。用户受过高等教育，有境外留学经历。",
    )
    
    # 性格维度
    personality = Personality(
        traits=["外向", "社交活跃", "领导力强"],
        social_activity="社交频繁，喜欢与人相聚",
        work_style="习惯于使用白板构思工作，期望提升领导力",
        description="社交频繁，性格外向，喜欢与人相聚。工作中习惯于使用白板构思工作，期望提升领导力。",
    )
    
    # 职业维度
    career = Career(
        occupation="科技公司中层管理者",
        company="阿里巴巴",
        industry="互联网/科技",
        work_location="浙江省杭州市南华区华海大厦B座",
        work_hours="每日平均工作时长11小时左右",
        commute_time="约20分钟",
        overtime_frequency="加班频繁",
        description="用户加班频繁，每日工作时间11小时左右，偶尔有跨城市出差，期望提升领导力，习惯于使用白板构思工作。技术研发方向，受过高等教育，有境外留学经历。",
    )
    
    # 饮食维度
    diet = Diet(
        preferences=["粤菜", "快餐", "咖啡饮品"],
        dining_style="外出就餐为主",
        dining_location="公司周边及购物中心",
        food_exploration="偶尔会去特色餐厅",
        description="用户经常外出就餐，偏好粤菜、快餐、咖啡饮品。偶尔会去特色餐厅和购物中心用餐，喜欢喝酒与咖啡。",
    )
    
    # 健康维度
    health = Health(
        fitness_habits=[],
        health_awareness="较低",
        medical_checkup="不会定期体检",
        health_products="不会关注保健品",
        description="用户经常熬夜加班，未有运动记录，具有一定的健康风险。",
    )
    
    # 餐厅偏好维度
    restaurants = Restaurants(
        preferred_types=["中餐厅", "小吃快餐", "特色美食", "咖啡馆"],
        dining_frequency="频繁外出就餐",
        review_habits="偶尔使用美团点评",
        photo_sharing="不会分享美食照片",
        online_ordering="经常使用美团、大众点评",
        description="用户经常在中餐厅、小吃快餐店用餐，工作日多在公司及周边餐饮场所就餐，休息日则会去购物中心和特色美食餐厅。",
    )
    
    # 运动维度
    sport = Sport(
        activities=[],
        frequency="很少运动",
        schedule="没有运动方面的规划",
        venues=[],
        description="未有运动记录，工作繁忙无暇锻炼。",
    )
    
    # 宠物维度
    pet = Pet(
        has_pet="否",
        description="暂无宠物",
    )
    
    # 购物维度
    shopping = Shopping(
        preferences=["食品", "酒水", "生活服务", "数码产品"],
        platforms=["美团", "淘宝", "京东"],
        brand_preference="注重品质",
        price_sensitivity="中等",
        promotion_habits="线上购物为主",
        description="用户经常使用手机购物，涉及食品、酒水、生活服务和数码产品等。购物活动多发生在家和公司附近，主要通过线上平台完成。",
    )
    
    # 交通出行维度
    transportation = Transportation(
        commute_method="自驾",
        commute_time="约20分钟",
        commute_peak="早晚高峰",
        long_distance="偶尔跨城市出差",
        travel_preferences=["自驾", "高铁", "打车", "地铁"],
        public_transport="市内通勤也常打车与地铁",
        description="用户经常使用汽车通勤，通勤家与公司之间行程多在5公里左右。常自驾宝马汽车，偶尔长途驾驶。市内通勤也常打车与地铁。",
    )
    
    # 汽车维度
    car = Car(
        has_car="是",
        car_brand="宝马",
        car_model="宝马3系",
        car_type="燃油车",
        usage_pattern="日常通勤为主，偶尔长途驾驶",
        description="有一辆黑色宝马汽车，偶尔长途驾驶。",
    )
    
    # 长途旅行维度
    long_travel = LongTravel(
        travel_style="自驾或打车",
        preferred_destinations=["杭州周边城市", "绍兴", "漳州"],
        travel_interests=["城市休闲", "美食体验"],
        travel_frequency="偶尔",
        travel_transport="自驾或打车",
        description="用户偶尔在杭州周边城市如绍兴、漳州等地短途旅行，出行多以自驾或打车为主，旅途中常用地图、社交和短视频应用，偏好城市休闲和美食体验。",
    )
    
    # 科技兴趣维度
    technology = Technology(
        interests=["AI技术", "大模型", "智能助手", "科技资讯"],
        focus_areas=["智能办公", "设备设置", "科技资讯"],
        devices=["OPPO手机", "OPPO Watch", "笔记本电脑"],
        tech_savvy_level="高",
        description="用户经常关注AI、大模型、智能助手等科技内容，频繁搜索、收藏相关网页和技术资料。日常涉及智能办公、设备设置、科技资讯等，具备较强的科技探索和学习习惯。",
    )
    
    # 摄影维度
    photography = Photography(
        shooting_subjects=["工作白板", "会议记录", "美食"],
        style="记录为主",
        focus="工作和生活记录",
        equipment=["OPPO手机"],
        description="主要用于工作记录（白板、会议内容）和日常生活记录。",
    )
    
    # 娱乐维度
    entertainment = Entertainment(
        activities=["刷短视频", "浏览新闻", "社交聚会"],
        content_preferences=["科技资讯", "社会热点", "时事新闻", "行业动态"],
        apps=["微信", "DingDing", "抖音", "微博", "小红书", "今日头条", "X"],
        social_activities=["同事聚餐", "朋友聚会"],
        offline_participation="较高",
        description="用户经常浏览新闻资讯类应用，关注社会热点、时事新闻、行业动态以及国外资讯。具有较强的新闻阅读习惯和国际视野。休闲时喜欢刷短视频、与朋友同事聚会。",
    )
    
    # 理财维度
    finance = Finance(
        investment_types=["证券", "基金"],
        financial_tools=["腾讯微证券", "银行APP"],
        financial_awareness="中等",
        daily_operations=["日常消费", "投资理财"],
        risk_preference="稳健",
        activity_pattern="偶尔关注",
        description="有一定的理财意识，使用腾讯微证券等工具进行投资理财，风格偏稳健。",
    )
    
    # 社交圈维度 - 使用 '{Role}: {Name}' 格式
    social_circle = SocialCircle(
        connections=[
            # 家庭成员
            "Spouse: 叶倩",
            # 同事
            "Colleague: 华晔",
            # 朋友
            "Friend: 丁丁",
        ],
    )
    
    # 创建 Person 对象
    person = Person(
        name="李浩然",
        basic_info=basic_info,
        personality=personality,
        career=career,
        diet=diet,
        health=health,
        restaurants=restaurants,
        sport=sport,
        pet=pet,
        shopping=shopping,
        transportation=transportation,
        car=car,
        long_travel=long_travel,
        technology=technology,
        photography=photography,
        entertainment=entertainment,
        finance=finance,
        social_circle=social_circle,
        trajectory_start=trajectory_start,
        trajectory_end=trajectory_end,
    )
    
    return person

print("Person creation function defined!")
# Out:
# Person creation function defined!

# %%
def normalize_timestamp(ts: str | int | float) -> str:
    """
    Normalize timestamp to 'YYYY-MM-DD HH:MM:SS' format.
    
    Handles both ISO 8601 strings and epoch milliseconds.
    
    Args:
        ts (`str | int | float`):
            Timestamp in ISO format (with/without 'T') or epoch milliseconds.
    
    Returns:
        `str`
            Normalized timestamp string in 'YYYY-MM-DD HH:MM:SS' format.
    """
    if isinstance(ts, str):
        # ISO string: replace 'T' with space
        return ts.replace("T", " ")
    elif isinstance(ts, (int, float)):
        # Epoch milliseconds -> datetime
        return datetime.fromtimestamp(ts / 1000.0).strftime("%Y-%m-%d %H:%M:%S")
    else:
        raise ValueError(f"Unsupported timestamp type: {type(ts)}")


def process_notes(file_path: Path) -> list[Session]:
    """Process note data and convert to sessions."""
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    sessions = []
    for item in data:
        timestamp = normalize_timestamp(item["createtime"])
        interaction = NoteInteraction(
            timestamp=timestamp,
            title=item.get("title"),
            content=item.get("content", ""),
            topic=item.get("topic"),
            entities=item.get("entities"),
        )
        message = interaction.to_message()
        session = Session(messages=[message])
        sessions.append(session)
    
    print(f"Processed {len(sessions)} notes")
    return sessions


def process_calendar(file_path: Path) -> list[Session]:
    """Process calendar data and convert to sessions."""
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    sessions = []
    for item in data:
        # Use start_time as the timestamp (per user requirement)
        timestamp = normalize_timestamp(item.get("start_time", item.get("created_at", "")))
        
        interaction = CalendarInteraction(
            timestamp=timestamp,
            id=item.get("id"),
            user_id=item.get("user_id"),
            title=item.get("title", ""),
            description=item.get("description", ""),
            start_time=item.get("start_time"),
            end_time=item.get("end_time"),
            is_all_day=item.get("is_all_day"),
            location=item.get("location"),
            attendees=item.get("attendees"),
            topic=item.get("topic"),
            reminder_minutes=item.get("reminder_minutes"),
            tags=item.get("tags"),
        )
        message = interaction.to_message()
        session = Session(messages=[message])
        sessions.append(session)
    
    print(f"Processed {len(sessions)} calendar events")
    return sessions


def process_voice_memos(file_path: Path) -> list[Session]:
    """Process voice memo data and convert to sessions."""
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    sessions = []
    for item in data:
        timestamp = normalize_timestamp(item.get("created_at", ""))
        
        interaction = VoiceMemoInteraction(
            timestamp=timestamp,
            id=item.get("id"),
            user_id=item.get("user_id"),
            transcript=item.get("transcript", ""),
            duration_seconds=item.get("duration_seconds", 0),
            scene=item.get("scene"),
            scene_description=item.get("scene_description"),
            has_noise=item.get("has_noise"),
            noise_type=item.get("noise_type"),
            is_fragmented=item.get("is_fragmented"),
            has_filler_words=item.get("has_filler_words"),
            key_info=item.get("key_info"),
            tags=item.get("tags"),
        )
        message = interaction.to_message()
        session = Session(messages=[message])
        sessions.append(session)
    
    print(f"Processed {len(sessions)} voice memos")
    return sessions


def process_todos(file_path: Path) -> list[Session]:
    """Process todo data and convert to sessions."""
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    sessions = []
    for item in data:
        timestamp = normalize_timestamp(item.get("createtime") or item.get("created_at", ""))
        
        interaction = TodoInteraction(
            timestamp=timestamp,
            id=item.get("id"),
            user_id=item.get("user_id"),
            created_at=item.get("created_at"),
            title=item.get("title", ""),
            content=item.get("content"),
            description=item.get("description"),
            due_date=item.get("due_date"),
            priority=item.get("priority"),
            is_completed=False,
            is_finished=False,
            topic=item.get("topic"),
            tags=item.get("tags"),
        )
        message = interaction.to_message()
        session = Session(messages=[message])
        sessions.append(session)

        timestamp = item.get("completed_at")
        if timestamp is not None:
            timestamp = normalize_timestamp(timestamp) 
            interaction = TodoInteraction(
                timestamp=timestamp,
                id=item.get("id"),
                user_id=item.get("user_id"),
                created_at=item.get("created_at"),
                title=item.get("title", ""),
                content=item.get("content"),
                description=item.get("description"),
                due_date=item.get("due_date"),
                priority=item.get("priority"),
                is_completed=True,
                is_finished=True,
                topic=item.get("topic"),
                tags=item.get("tags"),
            )
            message = interaction.to_message()
            session = Session(messages=[message])
            sessions.append(session)
    
    print(f"Processed {len(sessions)} todos")
    return sessions


def process_bills(file_path: Path) -> list[Session]:
    """Process bill data and convert to sessions."""
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    sessions = []
    for item in data:
        # Use transaction_time (epoch ms) as timestamp (per user requirement)
        timestamp = normalize_timestamp(item.get("transaction_time", 0))
        
        interaction = BillInteraction(
            timestamp=timestamp,
            id=item.get("id"),
            user_id=item.get("user_id"),
            entities=item.get("entities"),
            tags=item.get("tags"),
            bill_id=item.get("bill_id"),
            type=item.get("type"),
            transaction_type=item.get("transaction_type"),
            amount=item.get("amount"),
            payment_source=item.get("payment_source"),
            category=item.get("category"),
            merchant_name=item.get("merchant_name"),
            merchant_name_en=item.get("merchant_name_en"),
            product_name=item.get("product_name"),
            sys_record_id=item.get("sys_record_id"),
            currency=item.get("currency"),
            primary_amount=item.get("primary_amount"),
            primary_currency=item.get("primary_currency"),
        )
        message = interaction.to_message()
        session = Session(messages=[message])
        sessions.append(session)
    
    print(f"Processed {len(sessions)} bills")
    return sessions


def process_documents(file_path: Path) -> list[Session]:
    """Process document data and convert to sessions."""
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    sessions = []
    for item in data:
        # Use created_at as timestamp (per user requirement)
        timestamp = normalize_timestamp(item.get("created_at", ""))
        
        interaction = DocumentInteraction(
            timestamp=timestamp,
            id=item.get("id"),
            user_id=item.get("user_id"),
            entities=item.get("entities"),
            tags=item.get("tags"),
            title=item.get("title"),
            content=item.get("content"),
            page_count=item.get("page_count"),
            topic=item.get("topic"),
            format=item.get("format"),
        )
        message = interaction.to_message()
        session = Session(messages=[message])
        sessions.append(session)
    
    print(f"Processed {len(sessions)} documents")
    return sessions


def process_screens_txt(screen_dir: Path, trajectory_start: str, trajectory_end: str) -> list[Session]:
    """
    Process screen memo txt files and convert to sessions.
    
    Each txt file becomes a single-message session with a randomly assigned 
    timestamp within the trajectory window.
    
    Args:
        screen_dir (`Path`):
            Directory containing screen txt files (e.g., user_01_refined/screen/).
        trajectory_start: str
            Start of persona trajectory in 'YYYY-MM-DD HH:MM:SS' format.
        trajectory_end: str
            End of persona trajectory in 'YYYY-MM-DD HH:MM:SS' format.
    
    Returns:
        `list[Session]`
            List of sessions created from screen txt files.
    """
    # Find all .txt files recursively
    txt_files = list(screen_dir.rglob("*.txt"))
    
    if not txt_files:
        print("No screen txt files found")
        return []
    
    start_dt = datetime.fromisoformat(trajectory_start)
    end_dt = datetime.fromisoformat(trajectory_end)
    total_seconds = int((end_dt - start_dt).total_seconds())
    
    sessions = []
    for txt_path in txt_files:
        # Read txt content
        with open(txt_path, "r", encoding="utf-8") as f:
            content = f.read().strip()
        
        if not content:
            continue  # Skip empty files
        
        # Generate random timestamp within trajectory window
        random_offset = rng.randint(0, total_seconds)
        random_dt = start_dt + timedelta(seconds=random_offset)
        timestamp = random_dt.strftime("%Y-%m-%d %H:%M:%S")
        
        interaction = ScreenInteraction(
            timestamp=timestamp,
            content=content,
        )
        message = interaction.to_message()
        session = Session(messages=[message])
        sessions.append(session)
    
    print(f"Processed {len(sessions)} screen memos")
    return sessions


print("Functions defined successfully!")
# Out:
# Functions defined successfully!

# %%
# Phase 1: Process all timestamped interaction types
all_sessions = []

# Process notes
if NOTE_PATH.exists():
    note_sessions = process_notes(NOTE_PATH)
    all_sessions.extend(note_sessions)
else:
    print(f"Note file not found: {NOTE_PATH}")

# Process calendar
if CALENDAR_PATH.exists():
    calendar_sessions = process_calendar(CALENDAR_PATH)
    all_sessions.extend(calendar_sessions)
else:
    print(f"Calendar file not found: {CALENDAR_PATH}")

# Process voice memos
if VOICE_PATH.exists():
    voice_sessions = process_voice_memos(VOICE_PATH)
    all_sessions.extend(voice_sessions)
else:
    print(f"Voice memo file not found: {VOICE_PATH}")

# Process todos
if TODO_PATH.exists():
    todo_sessions = process_todos(TODO_PATH)
    all_sessions.extend(todo_sessions)
else:
    print(f"Todo file not found: {TODO_PATH}")

# Process bills
if BILL_PATH.exists():
    bill_sessions = process_bills(BILL_PATH)
    all_sessions.extend(bill_sessions)
else:
    print(f"Bill file not found: {BILL_PATH}")

# Process documents
if DOCUMENT_PATH.exists():
    document_sessions = process_documents(DOCUMENT_PATH)
    all_sessions.extend(document_sessions)
else:
    print(f"Document file not found: {DOCUMENT_PATH}")

print(f"\nTotal timestamped sessions collected: {len(all_sessions)}")

# Phase 2: Calculate trajectory range from timestamped sessions
if all_sessions:
    all_timestamps = []
    for sess in all_sessions:
        all_timestamps.append(datetime.fromisoformat(sess.started_at))
        all_timestamps.append(datetime.fromisoformat(sess.ended_at))
    
    min_time = min(all_timestamps)
    max_time = max(all_timestamps)
    
    print(f"\nTimestamped session time range:")
    print(f"  Earliest: {min_time}")
    print(f"  Latest:   {max_time}")
    
    # Randomly extend trajectory: 3~14 days before and after
    days_before = rng.randint(3, 14)
    days_after = rng.randint(3, 14)
    
    trajectory_start = (min_time - timedelta(days=days_before)).strftime("%Y-%m-%d %H:%M:%S")
    trajectory_end = (max_time + timedelta(days=days_after)).strftime("%Y-%m-%d %H:%M:%S")
    
    print(f"\nTrajectory range (with random extension):")
    print(f"  Start: {trajectory_start} (extended {days_before} days before)")
    print(f"  End:   {trajectory_end} (extended {days_after} days after)")
else:
    # Fallback if no sessions
    trajectory_start = "2024-09-01 00:00:00"
    trajectory_end = "2025-01-31 23:59:59"
    print("No timestamped sessions found, using default trajectory range")

# Phase 3: Process screen memos with random timestamps within the trajectory window
if SCREEN_DIR.exists():
    screen_sessions = process_screens_txt(SCREEN_DIR, trajectory_start, trajectory_end)
    all_sessions.extend(screen_sessions)
else:
    print(f"\nScreen directory not found: {SCREEN_DIR}")

print(f"\n✅ Total sessions (including screen memos): {len(all_sessions)}")
# Out:
# Processed 19 notes
# Processed 12 calendar events
# Processed 20 voice memos
# Processed 20 todos
# Processed 20 bills
# Processed 16 documents
#
# Total timestamped sessions collected: 107
#
# Timestamped session time range:
#   Earliest: 2024-06-17 10:06:00
#   Latest:   2025-01-05 21:13:00
#
# Trajectory range (with random extension):
#   Start: 2024-06-04 10:06:00 (extended 13 days before)
#   End:   2025-01-09 21:13:00 (extended 4 days after)
# Processed 20 screen memos
#
# ✅ Total sessions (including screen memos): 127

# %%
messages = [] 
all_sessions = sorted(
    all_sessions, 
    key=lambda x: x.messages[0].timestamp
)
for session in all_sessions:
    messages.extend(session.messages)

for i, message in enumerate(messages[1:], start=1):
    prev_msg_ts = datetime.fromisoformat(messages[i - 1].timestamp) 
    cur_msg_ts = datetime.fromisoformat(messages[i].timestamp) 
    if cur_msg_ts <= prev_msg_ts:
        cur_msg_ts = prev_msg_ts + timedelta(seconds=120) 
        message.timestamp = cur_msg_ts.strftime("%Y-%m-%d %H:%M:%S")

merged_sessions = []
current_session = None
print(f"Before Merge: {len(all_sessions)}")

for session in all_sessions:
    if current_session is None:
        current_session = session
    else:
        current_start_time = datetime.fromisoformat(current_session.messages[0].timestamp)
        new_end_time = datetime.fromisoformat(session.messages[-1].timestamp)
        
        total_span = new_end_time - current_start_time
        
        if total_span.days < 2:
            current_session = Session.merge([current_session, session])
        else:
            merged_sessions.append(current_session)
            current_session = session

if current_session is not None:
    merged_sessions.append(current_session)
all_sessions = merged_sessions
print(f"After Merge: {len(all_sessions)}")
# Out:
# Before Merge: 127
# After Merge: 54

# %%
# Create person with calculated trajectory range
person = create_person(trajectory_start, trajectory_end)
print(f"Created person: {person.name}")
print(f"Trajectory: {person.trajectory_start} -> {person.trajectory_end}")

# Add all sessions to the person
# Note: Person.add_grounded_session() automatically inserts sessions in chronological order
for session in all_sessions:
    person.add_grounded_session(session)

print(f"\nAdded {len(all_sessions)} sessions to person")
print(f"Total grounded sessions now: {person.num_grounded_sessions}")
# Out:
# Created person: 李浩然
# Trajectory: 2024-06-04 10:06:00 -> 2025-01-09 21:13:00
#
# Added 54 sessions to person
# Total grounded sessions now: 54

# %%
with open(OUTPUT_PATH, "w", encoding="utf-8") as f:
    f.write(person.model_dump_json(indent=2))

print(f"✅ Saved person with grounded sessions to: {OUTPUT_PATH}")
print(f"   Person: {person.name}")
print(f"   Grounded sessions: {person.num_grounded_sessions}")
print(f"   Trajectory: {person.trajectory_start} -> {person.trajectory_end}")
# Out:
# ✅ Saved person with grounded sessions to: data/user_02/processed/person.pkl
#    Person: 李浩然
#    Grounded sessions: 54
#    Trajectory: 2024-06-04 10:06:00 -> 2025-01-09 21:13:00

# %%
print("=" * 60)
print("Sample Sessions Preview")
print("=" * 60)

# Get grounded sessions and show first few
grounded = person.grounded_sessions
for i, sess in enumerate(grounded[:20]):
    print(f"\n--- Session {i+1} ---")
    print(f"Started at: {sess.started_at}")
    print(f"Messages: {len(sess.messages)}")
    for msg in sess.messages:
        content_preview = msg.content[:100] if len(msg.content) > 100 else msg.content
        print(f"  [{msg.name}] {content_preview}...")
# Out:
# ============================================================
# Sample Sessions Preview
# ============================================================
#
# --- Session 1 ---
# Started at: 2024-06-14 03:13:01
# Messages: 3
#   [Screen Memo] 用户在手机上看了以下内容：
# 标题: 西湖
# 来源: https://zh.wikipedia.org/wiki/%E8%A5%BF%E6%B9%96
#
# 摘要:
# 西湖位于中华人民共和国浙江省杭州旧城西侧，...
#   [Screen Memo] 用户在手机上看了以下内容：
# 标题: 人工智能
# 来源: https://zh.wikipedia.org/wiki/%E4%BA%BA%E5%B7%A5%E6%99%BA%E8%83%BD
#
# 摘要:
# 人...
#   [Screen Memo] 用户在手机上看了以下内容：
# 标题: 阿里巴巴和四十大盜
# 来源: https://zh.wikipedia.org/wiki/%E9%98%BF%E9%87%8C%E5%B7%B4%E5%B7%B4%E...
#
# --- Session 2 ---
# Started at: 2024-06-16 18:20:09
# Messages: 2
#   [Screen Memo] 用户在手机上看了以下内容：
# 标题: 管理学
# 来源: https://zh.wikipedia.org/wiki/%E7%AE%A1%E7%90%86%E5%AD%A6
#
# 摘要:
# 管理学是研究人類管理活...
#   [Document] 用户保存了一份文档《2024年度市场调研报告: 趋势与洞察》。
# 主题：work
# 格式：pdf
# 页数：7
# 内容：
# ### 市场调研报告
#
# #### 1. 调研背景
# 随着全球经济和科技的快速发展，市场竞争...
#
# --- Session 3 ---
# Started at: 2024-06-19 22:35:00
# Messages: 1
#   [Document] 用户保存了一份文档《提升团队协作效率的AI工具部署计划》。
# 主题：work
# 格式：docx
# 页数：7
# 内容：
# # 提升团队协作效率的AI工具部署计划
#
# ## 项目背景
# 随着科技行业竞争日益激烈，高效管...
#
# --- Session 4 ---
# Started at: 2024-06-27 11:24:12
# Messages: 1
#   [Document] 用户保存了一份文档《有效学习方法与实践》。
# 主题：study
# 格式：markdown
# 页数：1
# 内容：
# ### 什么是有效学习？
# 有效学习是一种通过正确的方法和工具，达到学习目标的过程。它并不仅仅依赖...
#
# --- Session 5 ---
# Started at: 2024-07-04 11:13:00
# Messages: 1
#   [Document] 用户保存了一份文档《家电使用说明：如何高效、安全地使用常见家电》。
# 主题：personal
# 格式：pdf
# 页数：1
# 内容：
# ### 家电使用说明
#
# #### 1. **电器安全使用基本原则**
# - 确...
#
# --- Session 6 ---
# Started at: 2024-07-08 04:25:43
# Messages: 3
#   [Screen Memo] 用户在手机上看了以下内容：
# 标题: 暗物质
# 来源: https://zh.wikipedia.org/wiki/%E6%9A%97%E7%89%A9%E8%B4%A8
#
# 摘要:
# 在宇宙学中，暗物質（英...
#   [Document] 用户保存了一份文档《基于团队协作的领导力提升实验报告》。
# 主题：study
# 格式：docx
# 页数：5
# 内容：
# ### 实验目的
# 探讨科技公司中层管理者如何通过优化团队协作和领导方式，提升团队绩效与个人...
#   [Document] 用户保存了一份文档《科技管理者的高效学习计划》。
# 主题：study
# 格式：markdown
# 页数：1
# 内容：
# ### 学习计划概览
# 科技公司中层管理者作为企业运营核心，需要持续提升领导力及专业能力。以...
#
# --- Session 7 ---
# Started at: 2024-07-10 19:24:10
# Messages: 1
#   [Screen Memo] 用户在手机上看了以下内容：
# 标题: 机器人
# 来源: https://zh.wikipedia.org/wiki/%E6%9C%BA%E5%99%A8%E4%BA%BA
#
# 摘要:
# 机器人（英語：Robo...
#
# --- Session 8 ---
# Started at: 2024-07-14 05:25:27
# Messages: 1
#   [Screen Memo] 用户在手机上看了以下内容：
# 标题: 电子商务
# 来源: https://zh.wikipedia.org/wiki/%E7%94%B5%E5%AD%90%E5%95%86%E5%8A%A1
#
# 摘要:
# 电...
#
# --- Session 9 ---
# Started at: 2024-07-16 14:55:00
# Messages: 1
#   [Document] 用户保存了一份文档《高效学习的核心方法》。
# 主题：study
# 格式：pdf
# 页数：9
# 内容：
# ### 第一部分：有效的学习方法
# #### 1. 确定学习目标
# 明确学习的最终目的，例如提高工作效率、掌握...
#
# --- Session 10 ---
# Started at: 2024-07-28 14:41:15
# Messages: 1
#   [Screen Memo] 用户在手机上看了以下内容：
# 标题: 吳越文化
# 来源: https://zh.wikipedia.org/wiki/%E5%90%B3%E8%B6%8A%E6%96%87%E5%8C%96
#
# 摘要:
# 吳...
#
# --- Session 11 ---
# Started at: 2024-08-03 12:17:00
# Messages: 1
#   [Document] 用户保存了一份文档《项目立项书模板》。
# 主题：work
# 格式：docx
# 页数：5
# 内容：
# # 项目立项书模板
#
# ## 一、项目基本信息
#
# ### 1. 项目名称
# 填写拟立项项目的完整名称，要求简明扼要...
#
# --- Session 12 ---
# Started at: 2024-08-20 15:24:04
# Messages: 1
#   [Screen Memo] 用户在手机上看了以下内容：
# 标题: 第9號交響曲 (貝多芬)
# 来源: https://zh.wikipedia.org/wiki/%E7%AC%AC9%E8%99%9F%E4%BA%A4%E9%9F%...
#
# --- Session 13 ---
# Started at: 2024-08-26 00:42:00
# Messages: 2
#   [Document] 用户保存了一份文档《基于智能技术的团队协作能力提升项目计划》。
# 主题：work
# 格式：docx
# 页数：9
# 内容：
# ### 项目背景
# 随着科技的发展，智能技术在工作场景中正逐步发挥重要作用。本项目旨在通...
#   [Document] 用户保存了一份文档《个人生活与职业风险保障保险单》。
# 主题：personal
# 格式：pdf
# 页数：9
# 内容：
# ### 个人信息
# - **姓名**: 李浩然
# - **年龄**: 32岁
# - **...
#
# --- Session 14 ---
# Started at: 2024-08-28 07:57:13
# Messages: 2
#   [Screen Memo] 用户在手机上看了以下内容：
# 标题: JavaScript
# 来源: https://zh.wikipedia.org/wiki/JavaScript
#
# 摘要:
# JavaScript（通常缩写为JS）是一...
#   [Screen Memo] 用户在手机上看了以下内容：
# 标题: 利昂内尔·梅西
# 来源: https://zh.wikipedia.org/wiki/%E5%88%A9%E6%98%82%E5%86%85%E5%B0%94%C2%...
#
# --- Session 15 ---
# Started at: 2024-09-02 18:39:24
# Messages: 2
#   [Screen Memo] 用户在手机上看了以下内容：
# 标题: 软件即服务
# 来源: https://zh.wikipedia.org/wiki/%E8%BD%AF%E4%BB%B6%E5%8D%B3%E6%9C%8D%E5%8A...
#   [Document] 用户保存了一份文档《部门周例会纪要》。
# 主题：work
# 格式：markdown
# 页数：1
# 内容：
# ### 部门周例会纪要
#
# **时间**: 2024年9月10日 10:00 AM
# **地点**: ...
#
# --- Session 16 ---
# Started at: 2024-09-06 14:38:00
# Messages: 3
#   [Note] 用户在便签中记录了《家庭WiFi信息备忘》
# 内容：家庭WiFi名称: HaoranHome_5G, 密码: LHR@2023Secure! 请勿分享。...
#   [Screen Memo] 用户在手机上看了以下内容：
# 标题: 粤菜
# 来源: https://zh.wikipedia.org/wiki/%E7%B2%A4%E8%8F%9C
#
# 摘要:
# 粤菜，又稱广东菜，是四大中國菜系之一。「嶺...
#   [Bill] 用户和 南华区星巴克咖啡馆 之间产生了一笔账单记录。
# 商品：美式咖啡（中杯）
# 金额：11.16 CNY
# 交易类型：支出
# 类别：零食
# 支付方式：现金...
#
# --- Session 17 ---
# Started at: 2024-09-14 20:45:00
# Messages: 1
#   [Bill] 用户和 东坡酒家(南华区店) 之间产生了一笔账单记录。
# 商品：东坡肘子套餐(配精酿啤酒)
# 金额：223.12 CNY
# 交易类型：支出
# 类别：餐饮
# 支付方式：银行卡...
#
# --- Session 18 ---
# Started at: 2024-09-16 23:58:00
# Messages: 2
#   [Note] 用户在便签中记录了《今天的思考与感悟》
# 内容：今天是一个忙碌但充实的日子。从早晨到办公室开始，我就一直在白板上规划项目的细节和团队的分工。虽然工作压力不小，但看到方案逐渐清晰，内心还是有些满足的。中午...
#   [Note] 用户在便签中记录了《无标题便签》
# 内容：今天在公司开了一场讨论会，白板上写满了各种思路和方案，看着这些内容，既感到充实又有些疲惫。下班后，和几个老朋友约了南华区的一家粤菜馆，点了几道特色菜，聊了聊最近...
#
# --- Session 19 ---
# Started at: 2024-09-19 05:33:32
# Messages: 2
#   [Screen Memo] 用户在手机上看了以下内容：
# 标题: 美食
# 来源: https://zh.wikipedia.org/wiki/%E7%BE%8E%E9%A3%9F
#
# 摘要:
# 美食也称珍馐，泛指任何品质极佳、厨工精湛且...
#   [Bill] 用户和 星巴克南华区天街店 之间产生了一笔账单记录。
# 商品：星冰乐+美式咖啡豆曲奇组合
# 金额：53.44 CNY
# 交易类型：支出
# 类别：零食
# 支付方式：现金...
#
# --- Session 20 ---
# Started at: 2024-09-21 12:36:00
# Messages: 2
#   [Bill] 用户和 星巴克(南华区万象城店) 之间产生了一笔账单记录。
# 商品：焦糖玛奇朵大杯 + 香草牛奶小盒饼干
# 金额：66.66 CNY
# 交易类型：支出
# 类别：零食
# 支付方式：银行卡...
#   [Bill] 用户和 南华区镜湖咖啡馆 之间产生了一笔账单记录。
# 商品：拿铁咖啡（中杯）+手工烘焙曲奇饼干
# 金额：39.98 CNY
# 交易类型：支出
# 类别：餐饮
# 支付方式：支付宝...

# %%
from datetime import datetime

# %%
s = datetime.fromisoformat("2024-05-29 20:29:00")
e = datetime.fromisoformat("2025-01-13 15:53:00")

a = datetime.fromisoformat("2024-06-04 10:06:00")
b = datetime.fromisoformat("2025-01-09 21:13:00")

# %%
(e - s) + (b - a)
# Out:
# datetime.timedelta(days=448, seconds=23460)
